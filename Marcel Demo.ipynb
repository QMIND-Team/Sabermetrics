# %% [markdown]
# # Marcel Model Demonstration

# %% [markdown]
# ### The league average function

# %%
def leagueAverage(df, perGame):
    dictionary = {}
    if perGame == 1:
        df = dc.perGameConversionAll(df, 1)
    for column in df:
        if type(df[column].values[0]) != str:
            dictionary[column] = df[column].mean()
    return dictionary

# %% [markdown]
# ### The Marcel Model

# %%
def marcelModel(stat, playerId, firstDf, secondDf, thirdDf, firstAvg, secondAvg, thirdAvg):

    # gather data for requested player in each season
    try:
        firstData = firstDf.loc[playerId]
        firstStat = firstData.loc[stat]
        firstIP = firstData.loc['IP']
    except KeyError:
        firstStat = firstAvg[stat]
        firstIP = firstAvg['IP']
    try:
        secondData = secondDf.loc[playerId]
        secondStat = secondData.loc[stat]
        secondIP = secondData.loc['IP']
    except KeyError:
        secondStat = secondAvg[stat]
        secondIP = secondAvg['IP']
    try:
        thirdData = thirdDf.loc[playerId]
        thirdStat = thirdData.loc[stat]
        thirdIP = thirdData.loc['IP']
    except KeyError:
        thirdStat = thirdAvg[stat]
        thirdIP = thirdAvg['IP']

    # calculate stat value used in calculations
    projStatValue = (firstStat*3)+(secondStat*2)+(thirdStat*1)

    # starting pitcher innings pitched value used in calculations
    projIP = (firstIP * 0.5) + (secondIP * 0.1) + 60

    # finding expected stat for each year incorporating total stat to total IP ratio
    expFirst = firstDf[stat].sum() / firstDf['IP'].sum() * firstIP * 3
    expSecond = secondDf[stat].sum() / secondDf['IP'].sum() * secondIP * 2
    expThird = thirdDf[stat].sum() / thirdDf['IP'].sum() * thirdIP * 1

    # sum of the three seasons expected stat
    expStatTotal = expFirst + expSecond + expThird
    expIPTotal = (firstIP * 3) + (secondIP * 2) + (thirdIP * 1)

    # calculate stat per IP ratio
    regressedStatTotal = expStatTotal / expIPTotal * 900

    statPerIP = (regressedStatTotal + projStatValue) / (900 + expIPTotal) / 2

    # getting the predicted stat output using the stat per IP ratio and the predicted IP calculated
    prediction = statPerIP * projIP
    return prediction

# %% [markdown]
# ### Find Toronto's Pitching Roster

# %%
import modules.data_processing.data_query as dq
import modules.data_processing.data_cleaning as dc
import modules.get_rosters as rosters
import pandas as pd
import numpy as np

dateRange = ["2015-04-01", "2017-12-01"]
teamName = "Toronto Blue Jays"

roster = rosters.createTeamRosters(teamName)
roster
# Out:
#                       0
# 0      Jacob Waguespack
# 1        Marcus Stroman
# 2        Thomas Pannone
# 3         Elvis Luciano
# 4        Matt Shoemaker
# 5             Tim Mayza
# 6         Aaron Sanchez
# 7       Clayton Richard
# 8   Julian Merryweather
# 9       Sean Reid-Foley
# 10        David Paulino
# 11          Ryan Tepera
# 12          Joe Biagini
# 13         Ryan Borucki
# 14        Clay Buchholz
# 15         David Phelps
# 16          Yennsy Diaz
# 17         Hector Perez
# 18       Trent Thornton
# 19         Sam Gaviglio
# 20            Ken Giles
# 21       Patrick Murphy
# 22         Justin Smoak
# 23         Rowdy Tellez
# 24         Devon Travis
# 25        Richard Urena
# 26        Dalton Pompey
# 27         Kevin Pillar
# 28       Jonathan Davis
# 29        Brandon Drury
# 30        Freddy Galvis
# 31       Randal Grichuk
# 32  Lourdes Gurriel Jr.
# 33    Teoscar Hernandez
# 34         Danny Jansen
# 35           Luke Maile
# 36        Reese McGuire
# 37       Billy McKinney
# 38      Kendrys Morales
# 39       Anthony Alford

# %% [markdown]
# ### Prepare the Marcel Dataframe

# %%
league = "al"
stats = ["ERA", "WHIP", "SO9"]
marcelStats = ["Name", "Age","Lev", "Year", "G", "GS", "IP"]
marcelStats.extend(stats)
marcelDF = dq.query("bref", marcelStats, dateRange)
marcelDF
# Out:
#                     Name  Age            Lev  Year   G  GS     IP    ERA  \
# 1          David Aardsma   33         MLB-NL  2015  33   0   30.2   4.70
# 2          Fernando Abad   29         MLB-AL  2015  62   0   47.2   4.15
# 3            A.J. Achter   26         MLB-AL  2015  11   0   13.1   6.75
# 4           Austin Adams   28         MLB-AL  2015  28   0   33.1   3.78
# 5          Nathan Adcock   27         MLB-NL  2015  13   0   18.0   6.00
# 6         Jeremy Affeldt   36         MLB-NL  2015  52   0   35.1   5.86
# 7          Andrew Albers   29         MLB-AL  2015   1   0    2.2   3.38
# 8            Matt Albers   32         MLB-AL  2015  30   0   37.1   1.21
# 9        Al Alburquerque   29         MLB-AL  2015  67   0   62.0   4.21
# 10       Scott Alexander   25         MLB-AL  2015   4   0    6.0   4.50
# 11            Cody Allen   26         MLB-AL  2015  70   0   70.0   2.96
# 12        Miguel Almonte   22         MLB-AL  2015   9   0    8.2   6.23
# 13         Dario Alvarez   26         MLB-NL  2015   6   0    3.2  12.27
# 14     Henderson Alvarez   25         MLB-NL  2015   4   4   22.1   6.45
# 15          Jose Alvarez   26         MLB-AL  2015  64   0   67.0   3.49
# 16          R.J. Alvarez   24         MLB-AL  2015  21   0   20.0   9.90
# 17        Alexi Amarista   26         MLB-NL  2015   1   0    0.1   0.00
# 18        Brett Anderson   27         MLB-NL  2015  31  31  180.1   3.69
# 19        Chase Anderson   27         MLB-NL  2015  27  27  153.1   4.28
# 20         Cody Anderson   24         MLB-AL  2015  15  15   91.1   3.05
# 21         Matt Andriese   25         MLB-AL  2015  25   8   65.2   4.11
# 22          Elvis Araujo   23         MLB-NL  2015  40   0   34.2   3.38
# 23          Chris Archer   26         MLB-AL  2015  34  34  212.0   3.23
# 24       Shawn Armstrong   24         MLB-AL  2015   8   0    8.0   2.25
# 25          Jonathan Aro   24         MLB-AL  2015   6   0   10.1   6.97
# 27          Jake Arrieta   29         MLB-NL  2015  33  33  229.0   1.77
# 28            Alec Asher   23         MLB-NL  2015   7   7   29.0   9.31
# 29        Scott Atchison   39         MLB-AL  2015  23   0   19.2   6.86
# 30      Phillippe Aumont   26         MLB-NL  2015   1   1    4.0  13.50
# 31           Luis Avilan   25         MLB-NL  2015  73   0   53.1   4.05
# ..                   ...  ...            ...   ...  ..  ..    ...    ...
# 755      Aaron Wilkerson   28         MLB-NL  2017   3   2   10.1   3.48
# 756      Taylor Williams   25         MLB-NL  2017   5   0    4.2   1.93
# 757      Trevor Williams   25         MLB-NL  2017  31  25  150.1   4.07
# 758          Alex Wilson   30         MLB-AL  2017  66   0   60.0   4.50
# 759        Justin Wilson   29  MLB-NL,MLB-AL  2017  65   0   58.0   3.41
# 760         Tyler Wilson   27         MLB-AL  2017   9   1   15.1   7.04
# 761         Alex Wimmers   28         MLB-AL  2017   6   0    7.1   4.91
# 762          Dan Winkler   27         MLB-NL  2017  16   0   14.1   2.51
# 763          Matt Wisler   24         MLB-NL  2017  20   1   32.1   8.35
# 764        Nick Wittgren   26         MLB-NL  2017  38   0   42.1   4.68
# 765  Asher Wojciechowski   28         MLB-NL  2017  25   8   62.1   6.50
# 766            Alex Wood   26         MLB-NL  2017  27  25  152.1   2.72
# 767           Blake Wood   31  MLB-NL,MLB-AL  2017  72   0   74.1   5.45
# 768          Hunter Wood   23         MLB-AL  2017   1   0    0.1   0.00
# 769          Travis Wood   30  MLB-AL,MLB-NL  2017  39  14   94.1   6.77
# 770     Brandon Woodruff   24         MLB-NL  2017   8   8   43.0   4.81
# 771      Brandon Workman   28         MLB-AL  2017  33   0   39.2   3.18
# 772         Vance Worley   29         MLB-NL  2017  24  12   71.2   6.91
# 773        Daniel Wright   26         MLB-AL  2017   5   2   19.2   4.58
# 774      Mike Wright Jr.   27         MLB-AL  2017  13   0   25.0   5.76
# 775        Steven Wright   32         MLB-AL  2017   5   5   24.0   8.25
# 776      Jimmy Yacabonis   25         MLB-AL  2017  14   0   20.2   4.35
# 777          Kirby Yates   30  MLB-NL,MLB-AL  2017  62   0   56.2   3.97
# 778         Gabriel Ynoa   24         MLB-AL  2017   9   4   34.2   4.15
# 779         Michael Ynoa   25         MLB-AL  2017  22   0   29.0   5.90
# 780          Chris Young   38         MLB-AL  2017  14   2   30.0   7.50
# 781        Rob Zastryzny   25         MLB-NL  2017   4   0   13.0   8.31
# 782         Brad Ziegler   37         MLB-NL  2017  53   0   47.0   4.79
# 783    Jordan Zimmermann   31         MLB-AL  2017  29  29  160.0   6.08
# 784            Tony Zych   26         MLB-AL  2017  45   0   40.2   2.66
#
#       WHIP   SO9
# 1    1.272  10.3
# 2    1.343   8.5
# 3    1.350   9.5
# 4    1.500   6.2
# 5    1.500   6.5
# 6    1.613   5.3
# 7    1.125   3.4
# 8    1.071   6.8
# 9    1.548   8.4
# 10   1.333   4.5
# 11   1.157  12.7
# 12   1.615  10.4
# 13   1.636   4.9
# 14   1.567   3.6
# 15   1.209   7.9
# 16   2.000  10.4
# 17   0.000   0.0
# 18   1.331   5.8
# 19   1.291   6.5
# 20   1.106   4.3
# 21   1.325   6.7
# 22   1.385   8.8
# 23   1.137  10.7
# 24   0.875  12.4
# 25   1.839   7.0
# 27   0.865   9.3
# 28   1.793   5.0
# 29   1.373   5.5
# 30   3.000   6.8
# 31   1.181   8.3
# ..     ...   ...
# 755  0.677   6.1
# 756  1.286   7.7
# 757  1.310   7.0
# 758  1.367   6.3
# 759  1.293  12.4
# 760  1.696   5.3
# 761  2.182   8.6
# 762  0.907  11.3
# 763  1.732   6.1
# 764  1.394   9.1
# 765  1.444   9.2
# 766  1.057   8.9
# 767  1.574  10.2
# 768  0.000   0.0
# 769  1.728   6.2
# 770  1.326   6.7
# 771  1.235   8.4
# 772  1.800   6.3
# 773  1.475   5.0
# 774  1.320  10.1
# 775  1.875   4.9
# 776  1.548   3.5
# 777  1.112  14.0
# 778  1.356   6.8
# 779  1.724   7.1
# 780  2.033   6.6
# 781  2.000   7.6
# 782  1.553   5.0
# 783  1.550   5.8
# 784  1.254   7.7
#
# [2232 rows x 10 columns]

# %% [markdown]
# ### Split Dataframe by league and into 3 seasons

# %%
dates = dc.convertDateStringToInt(dateRange)
firstDate = dates[1]
secondDate = dates[1] - 1
thirdDate = dates[0]

if league == 'al':
    lev = 'MLB-AL'
elif league == 'nl':
    lev = 'MLB-NL'

leagueDF = marcelDF[marcelDF['Lev'] == lev]
lgSeason1DF = leagueDF[leagueDF['Year'] == firstDate]
lgSeason2DF = leagueDF[leagueDF['Year'] == secondDate]
lgSeason3DF = leagueDF[leagueDF['Year'] == thirdDate]

firstAvg = leagueAverage(lgSeason1DF, 0)
secondAvg = leagueAverage(lgSeason2DF, 0)
thirdAvg = leagueAverage(lgSeason3DF, 0)

season1DF = marcelDF[marcelDF['Year'] == firstDate]
season2DF = marcelDF[marcelDF['Year'] == secondDate]
season3DF = marcelDF[marcelDF['Year'] == thirdDate]

# set search parameters
season1DF.set_index("Name", inplace=True)
season2DF.set_index("Name", inplace=True)
season3DF.set_index("Name", inplace=True)

rosterNames = list(roster[0])
statsPlus = ["IP"]
statsPlus.extend(stats)
stats1DF = season1DF[statsPlus].replace([np.inf, -np.inf], np.nan).dropna()
stats2DF = season2DF[statsPlus].replace([np.inf, -np.inf], np.nan).dropna()
stats3DF = season3DF[statsPlus].replace([np.inf, -np.inf], np.nan).dropna()
stats1DF
# Out:
#                         IP    ERA   WHIP   SO9
# Name
# Fernando Abad         43.2   3.30  1.237   7.6
# Austin L. Adams        5.0   3.60  2.400  18.0
# Tim Adleman          122.1   5.52  1.431   7.9
# Andrew Albers         41.0   3.51  1.293   8.1
# Matt Albers           61.0   1.62  0.852   9.3
# Al Alburquerque       18.0   2.50  1.000   7.0
# Raul Alcantara        24.0   7.13  1.417   4.5
# Sandy Alcantara        8.1   4.32  1.800  10.8
# Victor Alcantara       7.1   8.59  2.182   6.1
# Scott Alexander       69.0   2.48  1.319   7.7
# Cody Allen            67.1   2.94  1.158  12.3
# Miguel Almonte         2.0  13.50  3.500   0.0
# Dan Altavilla         46.2   4.24  1.350  10.0
# Jose Alvarado         29.2   3.64  1.112   8.8
# Dario Alvarez         16.1   2.76  2.020   9.4
# Henderson Alvarez     14.2   4.30  1.705   3.7
# Jose Alvarez          48.2   3.88  1.274   8.3
# Brett Anderson        55.1   6.34  1.699   6.2
# Chase Anderson       141.1   2.74  1.090   8.5
# Drew Anderson          2.1  23.14  3.000   7.7
# Tyler Anderson        86.0   4.81  1.326   8.5
# Matt Andriese         86.0   4.50  1.372   8.0
# Nori Aoki              1.0  27.00  3.000   0.0
# Jayson Aquino         13.1   7.43  1.575   8.8
# Victor Arano          10.2   1.69  0.938  11.0
# Chris Archer         201.0   4.07  1.259  11.1
# Shawn Armstrong       24.2   4.38  1.338   7.3
# Jake Arrieta         168.1   3.53  1.218   8.7
# Bronson Arroyo        71.0   7.35  1.592   5.7
# Alec Asher            60.0   5.25  1.400   7.1
# ...                    ...    ...    ...   ...
# Aaron Wilkerson       10.1   3.48  0.677   6.1
# Taylor Williams        4.2   1.93  1.286   7.7
# Trevor Williams      150.1   4.07  1.310   7.0
# Alex Wilson           60.0   4.50  1.367   6.3
# Justin Wilson         58.0   3.41  1.293  12.4
# Tyler Wilson          15.1   7.04  1.696   5.3
# Alex Wimmers           7.1   4.91  2.182   8.6
# Dan Winkler           14.1   2.51  0.907  11.3
# Matt Wisler           32.1   8.35  1.732   6.1
# Nick Wittgren         42.1   4.68  1.394   9.1
# Asher Wojciechowski   62.1   6.50  1.444   9.2
# Alex Wood            152.1   2.72  1.057   8.9
# Blake Wood            74.1   5.45  1.574  10.2
# Hunter Wood            0.1   0.00  0.000   0.0
# Travis Wood           94.1   6.77  1.728   6.2
# Brandon Woodruff      43.0   4.81  1.326   6.7
# Brandon Workman       39.2   3.18  1.235   8.4
# Vance Worley          71.2   6.91  1.800   6.3
# Daniel Wright         19.2   4.58  1.475   5.0
# Mike Wright Jr.       25.0   5.76  1.320  10.1
# Steven Wright         24.0   8.25  1.875   4.9
# Jimmy Yacabonis       20.2   4.35  1.548   3.5
# Kirby Yates           56.2   3.97  1.112  14.0
# Gabriel Ynoa          34.2   4.15  1.356   6.8
# Michael Ynoa          29.0   5.90  1.724   7.1
# Chris Young           30.0   7.50  2.033   6.6
# Rob Zastryzny         13.0   8.31  2.000   7.6
# Brad Ziegler          47.0   4.79  1.553   5.0
# Jordan Zimmermann    160.0   6.08  1.550   5.8
# Tony Zych             40.2   2.66  1.254   7.7
#
# [753 rows x 4 columns]

# %% [markdown]
# ### Predict Stats of Toronto's Pitching Roster

# %%
predictDF = pd.DataFrame(index=rosterNames, columns=stats)

for player in rosterNames:
    for stat in stats:
        predictDF.at[player, stat] = marcelModel(stat, player, stats1DF, stats2DF,
                                            stats3DF, firstAvg, secondAvg,thirdAvg)
predictDF
# Out:
#                          ERA     WHIP      SO9
# Jacob Waguespack     4.32572   1.2385  6.28622
# Marcus Stroman       4.89905  1.47207  7.70994
# Thomas Pannone       4.32572   1.2385  6.28622
# Elvis Luciano        4.32572   1.2385  6.28622
# Matt Shoemaker       3.87715  1.12518  6.06877
# Tim Mayza            3.79836  1.07847  6.09143
# Aaron Sanchez        3.35722  1.05431  5.18123
# Clayton Richard      5.52968  1.65486  7.94909
# Julian Merryweather  4.32572   1.2385  6.28622
# Sean Reid-Foley      4.32572   1.2385  6.28622
# David Paulino         4.1193  1.13503  5.87476
# Ryan Tepera          4.44015  1.30452  7.34468
# Joe Biagini          4.86437  1.40398  7.33668
# Ryan Borucki         4.32572   1.2385  6.28622
# Clay Buchholz        3.77533  1.02499  4.62567
# David Phelps         3.58726  1.11579  6.42276
# Yennsy Diaz          4.32572   1.2385  6.28622
# Hector Perez         4.32572   1.2385  6.28622
# Trent Thornton       4.32572   1.2385  6.28622
# Sam Gaviglio         4.42342  1.28527    6.434
# Ken Giles            3.79071  1.16236  7.44816
# Patrick Murphy       4.32572   1.2385  6.28622
# Justin Smoak         4.32572   1.2385  6.28622
# Rowdy Tellez         4.32572   1.2385  6.28622
# Devon Travis         4.32572   1.2385  6.28622
# Richard Urena        4.32572   1.2385  6.28622
# Dalton Pompey        4.32572   1.2385  6.28622
# Kevin Pillar         4.32572   1.2385  6.28622
# Jonathan Davis       4.32572   1.2385  6.28622
# Brandon Drury        4.32572   1.2385  6.28622
# Freddy Galvis        4.32572   1.2385  6.28622
# Randal Grichuk       4.32572   1.2385  6.28622
# Lourdes Gurriel Jr.  4.32572   1.2385  6.28622
# Teoscar Hernandez    4.32572   1.2385  6.28622
# Danny Jansen         4.32572   1.2385  6.28622
# Luke Maile           4.32572   1.2385  6.28622
# Reese McGuire        4.32572   1.2385  6.28622
# Billy McKinney       4.32572   1.2385  6.28622
# Kendrys Morales      4.32572   1.2385  6.28622
# Anthony Alford       4.32572   1.2385  6.28622
